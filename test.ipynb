# %%
from pywistor import Wistor

# %%
wistor = Wistor("Demo", "Demo", "Demo")
#wistor.execute_rule('ams_add_many_wkt',{"triples":f'(<http://wistor.nl/some_generated_id_1> "POINT(4.9 52.3)"^^geo:wktLiteral "{selected_object_type}")\n(<http://wistor.nl/some_generated_id_2> "POINT(4.8 51.4)"^^geo:wktLiteral "{selected_object_type}")'}, debug_mode=True)
# Out:
# {'app': '', 'fullAccess': True, 'appgraph': 'http://www.rws.nl/2017/vr/app', 'loggedIn': 'TRUE', 'repo': 'Demo', 'version': '1.05'}

# %%
selected_object_type = "pipe"
res = wistor.execute_rule('ams_add_many_wkt',{"triples":f'(<http://wistor.nl/some_generated_id_1> "POINT(4.9 52.3)"^^geo:wktLiteral "{selected_object_type}")'}, debug_mode=True)

# %%
res['success'] == True
# Out:
# False

# %%
res
# Out:
# {'debugMessages': [{'level': 'INFO',
#    'message': 'start rules with tag ams_add_many_wkt',
#    'mdc': {'Repo': 'Demo',
#     'User-Uri': 'http://wistor.nl/generatedUser#userf5534225-42cf-4af7-86d3-ec63a0b0f8d1',
#     'Username': 'Demo',
#     'IP-Address': '82.172.172.172'},
#    'timestamp': '2025-03-18T15:42:19.524'},
#   {'level': 'INFO',
#    'message': '\n#start sparql select\n\tPREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#> \n select distinct ?a \n where   {   ?a a/rdfs:subClassOf* <http://www.bbsgroep.nl/application/v2/Rule> . ?a <http://www.bbsgroep.nl/application/v2/tag> ?tag.  filter (?tag="ams_add_many_wkt") \t filter not exists {?a <http://www.bbsgroep.nl/application/v2/active> false }\toptional{?a <http://www.bbsgroep.nl/application/v2/salience> ?sal} } order by DESC(?sal)\n#end sparql select',
#    'mdc': {'Method-Name': 'select',
#     'Rule-Chain-Execution': '<none>',
#     'Repo': 'Demo',
#     'Username': 'Demo',
#     'IP-Address': '82.172.172.172',
#     'User-Uri': 'http://wistor.nl/generatedUser#userf5534225-42cf-4af7-86d3-ec63a0b0f8d1',
#     'Rule-Chain': '<none>',
#     ' Query-Id': 'a9ebff89-1b2a-43d2-a4da-4a05aec97d88',
#     'Start-Date': '2025-03-18T15:42:19.524864767'},
#    'timestamp': '2025-03-18T15:42:19.525'},
#   {'level': 'INFO',
#    'message': 'TAccess select success, row count=unknown',
#    'mdc': {'Method-Name': 'select',
#     'Rule-Chain-Execution': '<none>',
#     'Execution-Time': '0.007 seconds',
#     'Repo': 'Demo',
#     'Username': 'Demo',
#     'IP-Address': '82.172.172.172',
#     'User-Uri': 'http://wistor.nl/generatedUser#userf5534225-42cf-4af7-86d3-ec63a0b0f8d1',
#     'Rule-Chain': '<none>',
#     ' Query-Id': 'a9ebff89-1b2a-43d2-a4da-4a05aec97d88',
#     'End-Date': '2025-03-18T15:42:19.531954334',
#     'Start-Date': '2025-03-18T15:42:19.524864767'},
#    'timestamp': '2025-03-18T15:42:19.531'},
#   {'level': 'INFO',
#    'message': 'received request to execute rule http://wistor.nl/rules/data#ams_test with props: {"triples":"(<http://wistor.nl/some_generated_id_1> \\"POINT(4.9 52.3)\\"^^geo:wktLiteral)"}',
#    'mdc': {'Repo': 'Demo',
#     'User-Uri': 'http://wistor.nl/generatedUser#userf5534225-42cf-4af7-86d3-ec63a0b0f8d1',
#     'Username': 'Demo',
#     'IP-Address': '82.172.172.172'},
#    'timestamp': '2025-03-18T15:42:19.532'},
#   {'level': 'INFO',
#    'message': '\n#start sparql select\nPREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#> PREFIX owl:<http://www.w3.org/2002/07/owl#> select distinct ?type  ?label where { <http://wistor.nl/rules/data#ams_test> a/rdfs:subClassOf* ?type. ?type rdfs:subClassOf <http://www.bbsgroep.nl/application/v2/Rule>.<http://wistor.nl/rules/data#ams_test> <http://www.w3.org/2000/01/rdf-schema#label> ?label. }\n#end sparql select',
#    'mdc': {'Method-Name': 'select',
#     'Rule-Chain-Execution': '<none>',
#     'Repo': 'Demo',
#     'Username': 'Demo',
#     'IP-Address': '82.172.172.172',
#     'User-Uri': 'http://wistor.nl/generatedUser#userf5534225-42cf-4af7-86d3-ec63a0b0f8d1',
#     'Rule-Chain': '<none>',
#     ' Query-Id': '9d77b5b8-cf5e-434f-8bff-7f4a244aba77',
#     'Start-Date': '2025-03-18T15:42:19.532180914'},
#    'timestamp': '2025-03-18T15:42:19.532'},
#   {'level': 'INFO',
#    'message': 'TAccess select success, row count=unknown',
#    'mdc': {'Method-Name': 'select',
#     'Rule-Chain-Execution': '<none>',
#     'Execution-Time': '0.003 seconds',
#     'Repo': 'Demo',
#     'Username': 'Demo',
#     'IP-Address': '82.172.172.172',
#     'User-Uri': 'http://wistor.nl/generatedUser#userf5534225-42cf-4af7-86d3-ec63a0b0f8d1',
#     'Rule-Chain': '<none>',
#     ' Query-Id': '9d77b5b8-cf5e-434f-8bff-7f4a244aba77',
#     'End-Date': '2025-03-18T15:42:19.536080871',
#     'Start-Date': '2025-03-18T15:42:19.532180914'},
#    'timestamp': '2025-03-18T15:42:19.536'},
#   {'level': 'INFO',
#    'message': 'found a simple sparql rule ams_add_many_wkt',
#    'mdc': {'Repo': 'Demo',
#     'User-Uri': 'http://wistor.nl/generatedUser#userf5534225-42cf-4af7-86d3-ec63a0b0f8d1',
#     'Username': 'Demo',
#     'IP-Address': '82.172.172.172'},
#    'timestamp': '2025-03-18T15:42:19.536'},
#   {'level': 'INFO',
#    'message': '\n#start sparql select\n\tPREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>\n\tselect ?tag where {\n\t\t<http://wistor.nl/rules/data#ams_test> a/rdfs:subClassOf* <http://www.bbsgroep.nl/application/v2/Rule> .\n\t\t<http://wistor.nl/rules/data#ams_test> <http://www.bbsgroep.nl/application/v2/tag> ?tag .\n\t}\n\n#end sparql select',
#    'mdc': {'Method-Name': 'select',
#     'Rule-Chain-Execution': '<none>',
#     'Repo': 'Demo',
#     'Username': 'Demo',
#     'IP-Address': '82.172.172.172',
#     'User-Uri': 'http://wistor.nl/generatedUser#userf5534225-42cf-4af7-86d3-ec63a0b0f8d1',
#     'Rule-Chain': '<none>',
#     ' Query-Id': '8da76898-e4d2-4557-a585-ee0dca0312ec',
#     'Start-Date': '2025-03-18T15:42:19.536352338'},
#    'timestamp': '2025-03-18T15:42:19.536'},
#   {'level': 'INFO',
#    'message': 'TAccess select success, row count=unknown',
#    'mdc': {'Method-Name': 'select',
#     'Rule-Chain-Execution': '<none>',
#     'Execution-Time': '0.003 seconds',
#     'Repo': 'Demo',
#     'Username': 'Demo',
#     'IP-Address': '82.172.172.172',
#     'User-Uri': 'http://wistor.nl/generatedUser#userf5534225-42cf-4af7-86d3-ec63a0b0f8d1',
#     'Rule-Chain': '<none>',
#     ' Query-Id': '8da76898-e4d2-4557-a585-ee0dca0312ec',
#     'End-Date': '2025-03-18T15:42:19.539702029',
#     'Start-Date': '2025-03-18T15:42:19.536352338'},
#    'timestamp': '2025-03-18T15:42:19.539'},
#   {'level': 'INFO',
#    'message': '\n#start sparql select\n\tPREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>\n\n\tSELECT ?threadPoolUri ?corePoolSize ?maximumPoolSize WHERE {\n\t\t<http://wistor.nl/rules/data#ams_test> a/rdfs:subClassOf* <http://www.bbsgroep.nl/application/v2/Rule> .\n\t\t<http://wistor.nl/rules/data#ams_test> <http://www.bbsgroep.nl/application/v2/threadPool> ?threadPoolUri .\n\n\t\t?threadPoolUri a/rdfs:subClassOf* <http://www.bbsgroep.nl/application/v2/ThreadPool> .\n\t\tOPTIONAL {\n\t\t\t?threadPoolUri <http://www.bbsgroep.nl/application/v2/corePoolSize> ?corePoolSize .\n\t\t\t?threadPoolUri <http://www.bbsgroep.nl/application/v2/maximumPoolSize> ?maximumPoolSize .\n\t\t}\n\t}\n\n#end sparql select',
#    'mdc': {'Method-Name': 'select',
#     'Rule-Chain-Execution': '<none>',
#     'Repo': 'Demo',
#     'Username': 'Demo',
#     'IP-Address': '82.172.172.172',
#     'User-Uri': 'http://wistor.nl/generatedUser#userf5534225-42cf-4af7-86d3-ec63a0b0f8d1',
#     'Rule-Chain': '<none>',
#     ' Query-Id': '63f5a669-12da-4f37-8201-cb3b1f4ea7c9',
#     'Start-Date': '2025-03-18T15:42:19.539961959'},
#    'timestamp': '2025-03-18T15:42:19.54'},
#   {'level': 'INFO',
#    'message': 'TAccess select success, row count=unknown',
#    'mdc': {'Method-Name': 'select',
#     'Rule-Chain-Execution': '<none>',
#     'Execution-Time': '0.003 seconds',
#     'Repo': 'Demo',
#     'Username': 'Demo',
#     'IP-Address': '82.172.172.172',
#     'User-Uri': 'http://wistor.nl/generatedUser#userf5534225-42cf-4af7-86d3-ec63a0b0f8d1',
#     'Rule-Chain': '<none>',
#     ' Query-Id': '63f5a669-12da-4f37-8201-cb3b1f4ea7c9',
#     'End-Date': '2025-03-18T15:42:19.543948396',
#     'Start-Date': '2025-03-18T15:42:19.539961959'},
#    'timestamp': '2025-03-18T15:42:19.543'},
#   {'level': 'INFO',
#    'message': '\n#start sparql select\nPREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#> PREFIX owl:<http://www.w3.org/2002/07/owl#> select distinct ?sp ?label  where { optional {<http://wistor.nl/rules/data#ams_test> <http://www.w3.org/2000/01/rdf-schema#label> ?label.}optional {<http://wistor.nl/rules/data#ams_test> <http://www.bbsgroep.nl/application/v2/sparqlstring> ?sp}  }\n#end sparql select',
#    'mdc': {'Method-Name': 'select',
#     'Rule-Chain-Execution': '6f055b33-d445-4cab-9577-f365e4c90a31',
#     'Repo': 'Demo',
#     'Username': 'Demo',
#     'IP-Address': '82.172.172.172',
#     'User-Uri': 'http://wistor.nl/generatedUser#userf5534225-42cf-4af7-86d3-ec63a0b0f8d1',
#     'Rule-Chain': 'ams_add_many_wkt',
#     ' Query-Id': '62ff5927-5d83-444b-8cbb-161776fdb69e',
#     'Start-Date': '2025-03-18T15:42:19.544068737'},
#    'timestamp': '2025-03-18T15:42:19.544'},
#   {'level': 'INFO',
#    'message': 'TAccess select success, row count=unknown',
#    'mdc': {'Method-Name': 'select',
#     'Rule-Chain-Execution': '6f055b33-d445-4cab-9577-f365e4c90a31',
#     'Execution-Time': '0.003 seconds',
#     'Repo': 'Demo',
#     'Username': 'Demo',
#     'IP-Address': '82.172.172.172',
#     'User-Uri': 'http://wistor.nl/generatedUser#userf5534225-42cf-4af7-86d3-ec63a0b0f8d1',
#     'Rule-Chain': 'ams_add_many_wkt',
#     ' Query-Id': '62ff5927-5d83-444b-8cbb-161776fdb69e',
#     'End-Date': '2025-03-18T15:42:19.547255432',
#     'Start-Date': '2025-03-18T15:42:19.544068737'},
#    'timestamp': '2025-03-18T15:42:19.547'},
#   {'level': 'INFO',
#    'message': 'converted sparql query: PREFIX geo: <http://www.w3.org/2003/01/geo/wgs84_pos#>\nPREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>\nPREFIX wistor: <http://wistor.nl>\nINSERT\n{\n  GRAPH <http://wistor.nl/ams/wkt>\n  {\n    ?uri geo:asWKT ?wkt;\n    \t rdf:type  ?type\n  }\n}\nWHERE\n{\n  VALUES (?uri ?wkt ?type) { (<http://wistor.nl/some_generated_id_1> "POINT(4.9 52.3)"^^geo:wktLiteral) }\n}',
#    'mdc': {'Repo': 'Demo',
#     'User-Uri': 'http://wistor.nl/generatedUser#userf5534225-42cf-4af7-86d3-ec63a0b0f8d1',
#     'Username': 'Demo',
#     'IP-Address': '82.172.172.172'},
#    'timestamp': '2025-03-18T15:42:19.547'},
#   {'level': 'INFO',
#    'message': '\n#start sparql update\nPREFIX geo: <http://www.w3.org/2003/01/geo/wgs84_pos#>\nPREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>\nPREFIX wistor: <http://wistor.nl>\nINSERT\n{\n  GRAPH <http://wistor.nl/ams/wkt>\n  {\n    ?uri geo:asWKT ?wkt;\n    \t rdf:type  ?type\n  }\n}\nWHERE\n{\n  VALUES (?uri ?wkt ?type) { (<http://wistor.nl/some_generated_id_1> "POINT(4.9 52.3)"^^geo:wktLiteral) }\n}\n#end sparql update',
#    'mdc': {'Method-Name': 'insert',
#     'Rule-Chain-Execution': '6f055b33-d445-4cab-9577-f365e4c90a31',
#     'Repo': 'Demo',
#     'Username': 'Demo',
#     'IP-Address': '82.172.172.172',
#     'User-Uri': 'http://wistor.nl/generatedUser#userf5534225-42cf-4af7-86d3-ec63a0b0f8d1',
#     'Rule-Chain': 'ams_add_many_wkt',
#     ' Query-Id': 'f998c465-b4e2-4e05-a20e-153e84601372',
#     'Start-Date': '2025-03-18T15:42:19.547466498'},
#    'timestamp': '2025-03-18T15:42:19.547'},
#   {'level': 'WARN',
#    'message': 'Server reports problem: MALFORMED QUERY (enable debug logging for full details)',
#    'mdc': {'Method-Name': 'insert',
#     'Rule-Chain-Execution': '6f055b33-d445-4cab-9577-f365e4c90a31',
#     'Repo': 'Demo',
#     'Username': 'Demo',
#     'IP-Address': '82.172.172.172',
#     'User-Uri': 'http://wistor.nl/generatedUser#userf5534225-42cf-4af7-86d3-ec63a0b0f8d1',
#     'Rule-Chain': 'ams_add_many_wkt',
#     ' Query-Id': 'f998c465-b4e2-4e05-a20e-153e84601372',
#     'Start-Date': '2025-03-18T15:42:19.547466498'},
#    'timestamp': '2025-03-18T15:42:19.552'},
#   {'level': 'WARN',
#    'message': 'Server reports problem: MALFORMED QUERY (enable debug logging for full details)',
#    'mdc': {'Method-Name': 'insert',
#     'Rule-Chain-Execution': '6f055b33-d445-4cab-9577-f365e4c90a31',
#     'Repo': 'Demo',
#     'Username': 'Demo',
#     'IP-Address': '82.172.172.172',
#     'User-Uri': 'http://wistor.nl/generatedUser#userf5534225-42cf-4af7-86d3-ec63a0b0f8d1',
#     'Rule-Chain': 'ams_add_many_wkt',
#     ' Query-Id': 'f998c465-b4e2-4e05-a20e-153e84601372',
#     'Start-Date': '2025-03-18T15:42:19.547466498'},
#    'timestamp': '2025-03-18T15:42:19.557'},
#   {'level': 'WARN',
#    'message': 'Server reports problem: MALFORMED QUERY (enable debug logging for full details)',
#    'mdc': {'Method-Name': 'insert',
#     'Rule-Chain-Execution': '6f055b33-d445-4cab-9577-f365e4c90a31',
#     'Repo': 'Demo',
#     'Username': 'Demo',
#     'IP-Address': '82.172.172.172',
#     'User-Uri': 'http://wistor.nl/generatedUser#userf5534225-42cf-4af7-86d3-ec63a0b0f8d1',
#     'Rule-Chain': 'ams_add_many_wkt',
#     ' Query-Id': 'f998c465-b4e2-4e05-a20e-153e84601372',
#     'Start-Date': '2025-03-18T15:42:19.547466498'},
#    'timestamp': '2025-03-18T15:42:19.637'},
#   {'level': 'INFO',
#    'message': 'TAccess insert failure',
#    'mdc': {'Method-Name': 'insert',
#     'Rule-Chain-Execution': '6f055b33-d445-4cab-9577-f365e4c90a31',
#     'Execution-Time': '0.09 seconds',
#     'Repo': 'Demo',
#     'Username': 'Demo',
#     'IP-Address': '82.172.172.172',
#     'User-Uri': 'http://wistor.nl/generatedUser#userf5534225-42cf-4af7-86d3-ec63a0b0f8d1',
#     'Rule-Chain': 'ams_add_many_wkt',
#     ' Query-Id': 'f998c465-b4e2-4e05-a20e-153e84601372',
#     'End-Date': '2025-03-18T15:42:19.63792088',
#     'Start-Date': '2025-03-18T15:42:19.547466498'},
#    'timestamp': '2025-03-18T15:42:19.637'},
#   {'level': 'ERROR',
#    'message': 'could not execute rule ams_add_many_wkt, sparql insert failed',
#    'mdc': {'Repo': 'Demo',
#     'User-Uri': 'http://wistor.nl/generatedUser#userf5534225-42cf-4af7-86d3-ec63a0b0f8d1',
#     'Username': 'Demo',
#     'IP-Address': '82.172.172.172'},
#    'timestamp': '2025-03-18T15:42:19.638'},
#   {'level': 'ERROR',
#    'message': 'could not execute rule \'ams_add_many_wkt\'. sp error 22 . PREFIX geo: <http://www.w3.org/2003/01/geo/wgs84_pos#>\nPREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>\nPREFIX wistor: <http://wistor.nl>\nINSERT\n{\n  GRAPH <http://wistor.nl/ams/wkt>\n  {\n    ?uri geo:asWKT ?wkt;\n    \t rdf:type  ?type\n  }\n}\nWHERE\n{\n  VALUES (?uri ?wkt ?type) { (<http://wistor.nl/some_generated_id_1> "POINT(4.9 52.3)"^^geo:wktLiteral) }\n}',
#    'mdc': {'Repo': 'Demo',
#     'User-Uri': 'http://wistor.nl/generatedUser#userf5534225-42cf-4af7-86d3-ec63a0b0f8d1',
#     'Username': 'Demo',
#     'IP-Address': '82.172.172.172'},
#    'timestamp': '2025-03-18T15:42:19.638'},
#   {'level': 'INFO',
#    'message': 'engine results: 1 rules executed',
#    'mdc': {'Repo': 'Demo',
#     'User-Uri': 'http://wistor.nl/generatedUser#userf5534225-42cf-4af7-86d3-ec63a0b0f8d1',
#     'Username': 'Demo',
#     'IP-Address': '82.172.172.172'},
#    'timestamp': '2025-03-18T15:42:19.638'},
#   {'level': 'ERROR',
#    'message': '1 errors found',
#    'mdc': {'Repo': 'Demo',
#     'User-Uri': 'http://wistor.nl/generatedUser#userf5534225-42cf-4af7-86d3-ec63a0b0f8d1',
#     'Username': 'Demo',
#     'IP-Address': '82.172.172.172'},
#    'timestamp': '2025-03-18T15:42:19.638'}],
#  'success': False,
#  'errorMessage': 'rule execution error',
#  'errors': ['could not execute rule \'ams_add_many_wkt\'. sp error 22 . PREFIX geo: <http://www.w3.org/2003/01/geo/wgs84_pos#>PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>PREFIX wistor: <http://wistor.nl>INSERT{  GRAPH <http://wistor.nl/ams/wkt>  {    ?uri geo:asWKT ?wkt;    \\t rdf:type  ?type  }}WHERE{  VALUES (?uri ?wkt ?type) { (<http://wistor.nl/some_generated_id_1> \\"POINT(4.9 52.3)\\"^^geo:wktLiteral) }}']}
